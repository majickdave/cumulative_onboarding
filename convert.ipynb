# %%
import pandas as pd
df = pd.read_csv('data/patients.csv', encoding='latin1')
df['DateCreated'].to_csv('data/dates.csv', encoding='utf-8', index=False)

# %%
dates = pd.read_csv('data/dates.csv')
dates
# Out:
#     DateCreated
# 0     9/10/2025
# 1     2/17/2023
# 2     8/13/2021
# 3      1/3/2025
# 4     2/28/2024
# ..          ...
# 298   8/19/2021
# 299   1/20/2022
# 300   8/25/2021
# 301   8/16/2021
# 302    9/2/2021
#
# [303 rows x 1 columns]

# %%
df['DateCreated'] = pd.to_datetime(df['DateCreated'])

# %%
df['DateCreated'].dt.day_name().value_counts()
# Out:
# DateCreated
# Wednesday    60
# Friday       59
# Thursday     59
# Monday       53
# Tuesday      50
# Sunday       11
# Saturday     11
# Name: count, dtype: int64
